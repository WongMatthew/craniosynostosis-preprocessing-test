# %%
# %reset

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # New Data

# %%
# Import data
data = pd.read_csv(r"New Content Inventory.csv")

# %%
# see all columns
pd.set_option('max_columns', None)

# %%
data
# Out:
#                                              Unnamed: 0  \
# 0     X (refer to legend in row 1, column A for deta...
# 1                                                   NaN
# 2     Date Inclusion Criteria Reviewed (1st meeting ...
# 3                                                   NaN
# 4     31 May 2022;\nplease see comment under keyword...
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#                            Unnamed: 1  \
# 0                                   X
# 1                                 NaN
# 2     Inclusion Criteria 1: Relevance
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1802                              NaN
# 1803                              NaN
# 1804                              NaN
# 1805                              NaN
# 1806                              NaN
#
#                                        Unnamed: 2  \
# 0                                               X
# 1                                             NaN
# 2     Inclusion Criteria 2: Authority/Credibility
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1802                                          NaN
# 1803                                          NaN
# 1804                                          NaN
# 1805                                          NaN
# 1806                                          NaN
#
#                           Unnamed: 3  \
# 0                                  X
# 1                                NaN
# 2     Inclusion Criteria 3: Currency
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1802                             NaN
# 1803                             NaN
# 1804                             NaN
# 1805                             NaN
# 1806                             NaN
#
#                                              Unnamed: 4  \
# 0                                                     X
# 1                                                   NaN
# 2     Inclusion Criteria 4: Objectivity/Conflict of ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#                                          Unnamed: 5  \
# 0                                                 X
# 1                                               NaN
# 2     Inclusion Criteria 5: Evidence-based/informed
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 1802                                            NaN
# 1803                                            NaN
# 1804                                            NaN
# 1805                                            NaN
# 1806                                            NaN
#
#                                              Unnamed: 6  \
# 0                                                     X
# 1                                                   NaN
# 2     Inclusion Criteria 6: Readability/Accessibilit...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#                          Unnamed: 7                        Unnamed: 8  \
# 0                                 X                                 X
# 1                               NaN                               NaN
# 2     Content has been vetted (Y/N)  Content has been formatted (Y/N)
# 3                               NaN                               NaN
# 4                                 Y                                 Y
# ...                             ...                               ...
# 1802                            NaN                               NaN
# 1803                            NaN                               NaN
# 1804                            NaN                               NaN
# 1805                            NaN                               NaN
# 1806                            NaN                               NaN
#
#      Allows us to identify objects that are duplicated in the database, and link Digital Lab-generated ID#s to the objects in this spreadsheet  \
# 0                                                    ID
# 1                                                   NaN
# 2                                          Inventory ID
# 3                                                     1
# 4                                                     2
# ...                                                 ...
# 1802                                               1596
# 1803                                               1597
# 1804                                               1598
# 1805                                               1599
# 1806                                               1600
#
#      These are the titles of the objects; can include terms in search filter; include on blade.  \
# 0                                                     E
# 1                                                   NaN
# 2                                                 Title
# 3     [insert other DCD Advocacy Toolkit resources] ...
# 4     2020 Child-Bright Virtual Symposium Session Re...
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      This column lets us know what work needs to be done for the object to be web-ready   \
# 0                                                     X
# 1                                                   NaN
# 2                                                Status
# 3                                     May need updating
# 4                                             Screening
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Part of algorthim prompting updates to content, so the appropriate person is alerted/contacted  \
# 0                                                    ID
# 1                  For new or not yet updated content:
# 2                                    Person responsible
# 3                                             Stephanie
# 4                                         Claire/Salina
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Use for algorithm to prompt updates to objects. These would be back-up people to support updates  \
# 0                                                    ID
# 1                                                   NaN
# 2                                       Others involved
# 3                                               Jill Z.
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      only relevant when the object is not yet web-ready, or needs revisions (does not need to be part of database).   \
# 0                                                     I
# 1                                                   NaN
# 2                                         Required work
# 3                  Review to ensure web-ready; add tags
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      internal use to allow us to track progress on updates to make objects web-ready  \
# 0                                                     X
# 1                                                   NaN
# 2                               Lit search request date
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      For new or not yet updated content:   \
# 0                                      ID
# 1                                     NaN
# 2                  Target completion date
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1802                                  NaN
# 1803                                  NaN
# 1804                                  NaN
# 1805                                  NaN
# 1806                                  NaN
#
#      Include in algorithm to prompt updates so we know where to go  (i.e. the program is responsible for maintaining the object)  \
# 0                                                    ID
# 1                                                   NaN
# 2     Program to follow-up with (SH/BCCH program res...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Info to include on blade  \
# 0                          ID
# 1                      SOURCE
# 2                    External
# 3                    Internal
# 4                    External
# ...                       ...
# 1802                      NaN
# 1803                      NaN
# 1804                      NaN
# 1805                      NaN
# 1806                      NaN
#
#                              Info to include on blade.1  \
# 0                                                     E
# 1                                                   NaN
# 2              Author(s) (or name of org. if no author)
# 3                    Ivonne M. , OT & Stephanie G. , OT
# 4     Child-Bright Network and Strategy for Patient-...
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Exclude from search terms; For internal use only (no longer to appear on the blade)  \
# 0                                                     E
# 1                                                   NaN
# 2                                          Date created
# 3                                                   NaN
# 4                                                  2020
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Exclude from search term; Content - include on blade  \
# 0                                                     E
# 1                                                   NaN
# 2     Date of last update (©related to website that ...
# 3                                                   NaN
# 4                                                  2022
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Exclude from search terms; Include on blade to allow users to access the external resource  \
# 0                                                     E
# 1                                                   NaN
# 2                                                  Link
# 3                                                   NaN
# 4         https://www.child-bright.ca/virtual-symposium
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      For algorithm to prompt us to update object for currency  \
# 0                                                    ID
# 1                                                   NaN
# 2                                     Date Link Checked
# 3                                                   NaN
# 4                                          May 31, 2022
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#                                        Unnamed: 24  \
# 0                                                E
# 1                                              NaN
# 2                                  Target Audience
# 3                                              NaN
# 4     clinicians, researchers, families/caregivers
# ...                                            ...
# 1802                                           NaN
# 1803                                           NaN
# 1804                                           NaN
# 1805                                           NaN
# 1806                                           NaN
#
#      No longer using this tag, in order to simplify the user experience  \
# 0                                                     E
# 1                                                   NaN
# 2                                            Profession
# 3                                            DO NOT USE
# 4                                                   all
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      This info appears on the blade but no longer being used as a filter in order to simplify the user experience  \
# 0                                                     E
# 1                                                   NaN
# 2                                        Resource type
# 3                                                   NaN
# 4                                        Video or audio
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      For internal use so the person uploading the resource knows what type of file format to save it in or look for to upload  \
# 0                                                    ID
# 1                                                   NaN
# 2                                           File Format
# 3                                                   NaN
# 4                                              Web link
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#                     Navigation                                Navigation.1  \
# 0                           ID                                          ID
# 1                          NaN                                         NaN
# 2         Master Tag (Level 1)                                    Level 2A
# 3                          NaN                                         NaN
# 4     Making Treatment Choices  Learn About Treatment, Care and Activities
# ...                        ...                                         ...
# 1802                       NaN                                         NaN
# 1803                       NaN                                         NaN
# 1804                       NaN                                         NaN
# 1805                       NaN                                         NaN
# 1806                       NaN                                         NaN
#
#                                    Navigation.2 Navigation.3  \
# 0                                            ID           ID
# 1                                           NaN          NaN
# 2                                      Level 3A    Level 4A
# 3                                           NaN          NaN
# 4     Function, Activity and 'How To' Resources          NaN
# ...                                         ...          ...
# 1802                                        NaN          NaN
# 1803                                        NaN          NaN
# 1804                                        NaN          NaN
# 1805                                        NaN          NaN
# 1806                                        NaN          NaN
#
#                                     Navigation.4  \
# 0                                             ID
# 1                                            NaN
# 2                                       Level 2B
# 3                                            NaN
# 4     Learn About Treatment, Care and Activities
# ...                                          ...
# 1802                                         NaN
# 1803                                         NaN
# 1804                                         NaN
# 1805                                         NaN
# 1806                                         NaN
#
#                              Navigation.5 Navigation.6 Navigation.7  \
# 0                                      ID           ID           ID
# 1                                     NaN          NaN          NaN
# 2                                Level 3B     Level 4B     Level 2C
# 3                                     NaN          NaN          NaN
# 4     Health Condition-specific Resources          NaN          NaN
# ...                                   ...          ...          ...
# 1802                                  NaN          NaN          NaN
# 1803                                  NaN          NaN          NaN
# 1804                                  NaN          NaN          NaN
# 1805                                  NaN          NaN          NaN
# 1806                                  NaN          NaN          NaN
#
#      Navigation.8 Navigation.9  \
# 0              ID           ID
# 1             NaN          NaN
# 2        Level 3C     Level 4C
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 1802          NaN          NaN
# 1803          NaN          NaN
# 1804          NaN          NaN
# 1805          NaN          NaN
# 1806          NaN          NaN
#
#      For team to reference when tagging information hierarchy  \
# 0                                                     X
# 1                                                   NaN
# 2                              Old Master Tag (Level 1)
# 3                                                   NaN
# 4                                          Intervention
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Content to include on blade; exclude from search terms            Filter  \
# 0                                                  Tags                   NaN
# 1                                                     E                     E
# 2                                           Description      Health condition
# 3                                                   NaN                   DCD
# 4     The 2020 CHILD-BRIGHT Virtual Symposium was a ...                 Other
# ...                                                 ...                   ...
# 1802                                                NaN                   NaN
# 1803                                                NaN                   NaN
# 1804                                                NaN                   NaN
# 1805                                                NaN                   NaN
# 1806                                                NaN                   NaN
#
#            Filter.1                                       Search terms  \
# 0               NaN                                                NaN
# 1                 E                                                  E
# 2     Area of Focus            Keywords (see tags tab for information)
# 3               NaN                                                NaN
# 4               NaN  webinars, congenital heart disease, genomic te...
# ...             ...                                                ...
# 1802            NaN                                                NaN
# 1803            NaN                                                NaN
# 1804            NaN                                                NaN
# 1805            NaN                                                NaN
# 1806            NaN                                                NaN
#
#                     Filter.2  \
# 0                        NaN
# 1                         ID
# 2     Learning Event?  (Y/N)
# 3                          N
# 4                          Y
# ...                      ...
# 1802                     NaN
# 1803                     NaN
# 1804                     NaN
# 1805                     NaN
# 1806                     NaN
#
#              Toggle for audience (clinician vs. family)  \
# 0                                                     E
# 1                       Relationship to other resources
# 2               Corresponding clinician/parent resource
# 3     Management of Developmental Coordination Disor...
# 4                                                     N
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Recommended for you' tag (algorithm for proposing new resources for the user to explore)  \
# 0                                                     E
# 1                                                   NaN
# 2                     Sibling resources e.g. next steps
# 3       DCD saved search; DCD management brief overview
# 4                                                     N
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      For internal use in the database.  \
# 0                                   ID
# 1                                  NaN
# 2                                Notes
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 1802                               NaN
# 1803                               NaN
# 1804                               NaN
# 1805                               NaN
# 1806                               NaN
#
#      Used within algorithm to prompt updates to objects - directs us to the relevant content expert  \
# 0                                                    ID
# 1                                                   NaN
# 2                                   Person recommending
# 3                                             Ivonne M.
# 4                                                   Kim
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Filter.3  \
# 0           E
# 1         NaN
# 2         Age
# 3         NaN
# 4         All
# ...       ...
# 1802      NaN
# 1803      NaN
# 1804      NaN
# 1805      NaN
# 1806      NaN
#
#      This information can populate a field on the 'blades' for each object  \
# 0                                                     E
# 1                                                   NaN
# 2                                              Location
# 3                                                   NaN
# 4                                           Canada-Wide
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      This is the order of resources as of 2021Sep9. Delete this when it's not needed anymore  \
# 0                                                     X
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   901
# 4                                                  1360
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Thumbnail images for each object for users to see when browsing  \
# 0                                                     E
# 1                                                   NaN
# 2                                           Thumbnails
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Content - object 'rating' based on accessibility characteristics. Rating levels TBD. Could be on the blades or could be an icon on the thumbnail view (advise as to which is best approach)  \
# 0                                                     E
# 1                                                   NaN
# 2                                        Accessibility
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Exclude from search terms; filter, could be part of advanced search; can include as info on blade  \
# 0                                                     X
# 1                                                   NaN
# 2                        Audience level (tag names TBC)
# 3                                                   NaN
# 4                                      original sources
# ...                                                 ...
# 1802                                                NaN
# 1803                                                NaN
# 1804                                                NaN
# 1805                                                NaN
# 1806                                                NaN
#
#      Unnamed: 54
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1802         NaN
# 1803         NaN
# 1804         NaN
# 1805         NaN
# 1806         NaN
#
# [1807 rows x 55 columns]

# %%
data.loc[[2]]
# Out:
#                                           Unnamed: 0  \
# 2  Date Inclusion Criteria Reviewed (1st meeting ...
#
#                         Unnamed: 1  \
# 2  Inclusion Criteria 1: Relevance
#
#                                     Unnamed: 2  \
# 2  Inclusion Criteria 2: Authority/Credibility
#
#                        Unnamed: 3  \
# 2  Inclusion Criteria 3: Currency
#
#                                           Unnamed: 4  \
# 2  Inclusion Criteria 4: Objectivity/Conflict of ...
#
#                                       Unnamed: 5  \
# 2  Inclusion Criteria 5: Evidence-based/informed
#
#                                           Unnamed: 6  \
# 2  Inclusion Criteria 6: Readability/Accessibilit...
#
#                       Unnamed: 7                        Unnamed: 8  \
# 2  Content has been vetted (Y/N)  Content has been formatted (Y/N)
#
#   Allows us to identify objects that are duplicated in the database, and link Digital Lab-generated ID#s to the objects in this spreadsheet  \
# 2                                       Inventory ID
#
#   These are the titles of the objects; can include terms in search filter; include on blade.  \
# 2                                              Title
#
#   This column lets us know what work needs to be done for the object to be web-ready   \
# 2                                             Status
#
#   Part of algorthim prompting updates to content, so the appropriate person is alerted/contacted  \
# 2                                 Person responsible
#
#   Use for algorithm to prompt updates to objects. These would be back-up people to support updates  \
# 2                                    Others involved
#
#   only relevant when the object is not yet web-ready, or needs revisions (does not need to be part of database).   \
# 2                                      Required work
#
#   internal use to allow us to track progress on updates to make objects web-ready  \
# 2                            Lit search request date
#
#   For new or not yet updated content:   \
# 2               Target completion date
#
#   Include in algorithm to prompt updates so we know where to go  (i.e. the program is responsible for maintaining the object)  \
# 2  Program to follow-up with (SH/BCCH program res...
#
#   Info to include on blade                Info to include on blade.1  \
# 2                 External  Author(s) (or name of org. if no author)
#
#   Exclude from search terms; For internal use only (no longer to appear on the blade)  \
# 2                                       Date created
#
#   Exclude from search term; Content - include on blade  \
# 2  Date of last update (©related to website that ...
#
#   Exclude from search terms; Include on blade to allow users to access the external resource  \
# 2                                               Link
#
#   For algorithm to prompt us to update object for currency      Unnamed: 24  \
# 2                                  Date Link Checked        Target Audience
#
#   No longer using this tag, in order to simplify the user experience  \
# 2                                         Profession
#
#   This info appears on the blade but no longer being used as a filter in order to simplify the user experience  \
# 2                                     Resource type
#
#   For internal use so the person uploading the resource knows what type of file format to save it in or look for to upload  \
# 2                                        File Format
#
#              Navigation Navigation.1 Navigation.2 Navigation.3 Navigation.4  \
# 2  Master Tag (Level 1)     Level 2A     Level 3A    Level 4A      Level 2B
#
#   Navigation.5 Navigation.6 Navigation.7 Navigation.8 Navigation.9  \
# 2     Level 3B     Level 4B     Level 2C     Level 3C     Level 4C
#
#   For team to reference when tagging information hierarchy  \
# 2                           Old Master Tag (Level 1)
#
#   Content to include on blade; exclude from search terms            Filter  \
# 2                                        Description      Health condition
#
#         Filter.1                             Search terms  \
# 2  Area of Focus  Keywords (see tags tab for information)
#
#                  Filter.2 Toggle for audience (clinician vs. family)  \
# 2  Learning Event?  (Y/N)    Corresponding clinician/parent resource
#
#   Recommended for you' tag (algorithm for proposing new resources for the user to explore)  \
# 2                  Sibling resources e.g. next steps
#
#   For internal use in the database.  \
# 2                             Notes
#
#   Used within algorithm to prompt updates to objects - directs us to the relevant content expert  \
# 2                                Person recommending
#
#   Filter.3  \
# 2      Age
#
#   This information can populate a field on the 'blades' for each object  \
# 2                                           Location
#
#   This is the order of resources as of 2021Sep9. Delete this when it's not needed anymore  \
# 2                                                NaN
#
#   Thumbnail images for each object for users to see when browsing  \
# 2                                        Thumbnails
#
#   Content - object 'rating' based on accessibility characteristics. Rating levels TBD. Could be on the blades or could be an icon on the thumbnail view (advise as to which is best approach)  \
# 2                                     Accessibility
#
#   Exclude from search terms; filter, could be part of advanced search; can include as info on blade  \
# 2                     Audience level (tag names TBC)
#
#   Unnamed: 54
# 2         NaN

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Allows us to identify objects that are duplicated in the database, and link Digital Lab-generated ID#s to the objects in this spreadsheet',
#        'These are the titles of the objects; can include terms in search filter; include on blade.',
#        'This column lets us know what work needs to be done for the object to be web-ready ',
#        'Part of algorthim prompting updates to content, so the appropriate person is alerted/contacted',
#        'Use for algorithm to prompt updates to objects. These would be back-up people to support updates',
#        'only relevant when the object is not yet web-ready, or needs revisions (does not need to be part of database). ',
#        'internal use to allow us to track progress on updates to make objects web-ready',
#        'For new or not yet updated content: ',
#        'Include in algorithm to prompt updates so we know where to go  (i.e. the program is responsible for maintaining the object)',
#        'Info to include on blade', 'Info to include on blade.1',
#        'Exclude from search terms; For internal use only (no longer to appear on the blade)',
#        'Exclude from search term; Content - include on blade',
#        'Exclude from search terms; Include on blade to allow users to access the external resource',
#        'For algorithm to prompt us to update object for currency',
#        'Unnamed: 24',
#        'No longer using this tag, in order to simplify the user experience',
#        'This info appears on the blade but no longer being used as a filter in order to simplify the user experience',
#        'For internal use so the person uploading the resource knows what type of file format to save it in or look for to upload',
#        'Navigation', 'Navigation.1', 'Navigation.2', 'Navigation.3',
#        'Navigation.4', 'Navigation.5', 'Navigation.6', 'Navigation.7',
#        'Navigation.8', 'Navigation.9',
#        'For team to reference when tagging information hierarchy',
#        'Content to include on blade; exclude from search terms', 'Filter',
#        'Filter.1', 'Search terms', 'Filter.2',
#        'Toggle for audience (clinician vs. family)',
#        'Recommended for you' tag (algorithm for proposing new resources for the user to explore)',
#        'For internal use in the database.',
#        'Used within algorithm to prompt updates to objects - directs us to the relevant content expert',
#        'Filter.3',
#        'This information can populate a field on the 'blades' for each object',
#        'This is the order of resources as of 2021Sep9. Delete this when it's not needed anymore',
#        'Thumbnail images for each object for users to see when browsing',
#        'Content - object 'rating' based on accessibility characteristics. Rating levels TBD. Could be on the blades or could be an icon on the thumbnail view (advise as to which is best approach)',
#        'Exclude from search terms; filter, could be part of advanced search; can include as info on blade',
#        'Unnamed: 54'],
#       dtype='object')

# %%
# drop columns that contain 'x'
data = data.drop([
    'Unnamed: 0', 
    'Unnamed: 1',
    'Unnamed: 2',
    'Unnamed: 3',
    'Unnamed: 4',
    'Unnamed: 5',
    'Unnamed: 6',
    'Unnamed: 7',
    'Unnamed: 8',
    'This column lets us know what work needs to be done for the object to be web-ready ',
    'internal use to allow us to track progress on updates to make objects web-ready',
    'No longer using this tag, in order to simplify the user experience',
    'This info appears on the blade but no longer being used as a filter in order to simplify the user experience',
    'For team to reference when tagging information hierarchy',
    'This is the order of resources as of 2021Sep9. Delete this when it\'s not needed anymore',
    'Exclude from search terms; filter, could be part of advanced search; can include as info on blade',
    'Unnamed: 54'
], axis = 1)

# %%
data = data.drop([0, 1, 2])
data = data.reset_index(drop=True)

# %%
new_data = data.copy()

# %%
new_data.columns = [
    'Inventory ID',
    'Title',
    'Person responsible',
    'Others involved',
    'Required work',
    'Target completion date',
    'Program to follow-up with (SH/BCCH program responsible)',
    'External',
    'Author(s) (or name of org. if no author)',
    'Date created',
    'Date of last update (©related to website that is linked, not necessarily the resource)',
    'Link',
    'Date Link Checked',
    'Target Audience',
    'File Format',
    'Master Tag (Level 1)',
    'Level 2A',
    'Level 3A',
    'Level 4A',
    'Level 2B',
    'Level 3B',
    'Level 4B',
    'Level 2C',
    'Level 3C',
    'Level 4C',
    'Description',
    'Health condition',
    'Area of Focus',
    'Keywords (see tags tab for information)',
    'Learning Event?  (Y/N)',
    'Corresponding clinician/parent resource',
    'Sibling resources e.g. next steps',
    'Notes',
    'Person recommending',
    'Age',
    'Location',
    'Thumbnails',
    'Accessibility',
]

# %%
new_data
# Out:
#      Inventory ID                                              Title  \
# 0               1  [insert other DCD Advocacy Toolkit resources] ...
# 1               2  2020 Child-Bright Virtual Symposium Session Re...
# 2               3                          360 Cognitive Connections
# 3               4  5. Plan A: Standardized measures of IQ and dev...
# 4               6  A Clinical Application Guide to Standardized W...
# ...           ...                                                ...
# 1799         1596                                                NaN
# 1800         1597                                                NaN
# 1801         1598                                                NaN
# 1802         1599                                                NaN
# 1803         1600                                                NaN
#
#      Person responsible Others involved                         Required work  \
# 0             Stephanie         Jill Z.  Review to ensure web-ready; add tags
# 1         Claire/Salina             NaN                                   NaN
# 2                Claire             NaN                                   NaN
# 3                Claire             NaN                                   NaN
# 4                Debbie             NaN                                   NaN
# ...                 ...             ...                                   ...
# 1799                NaN             NaN                                   NaN
# 1800                NaN             NaN                                   NaN
# 1801                NaN             NaN                                   NaN
# 1802                NaN             NaN                                   NaN
# 1803                NaN             NaN                                   NaN
#
#      Target completion date  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1799                    NaN
# 1800                    NaN
# 1801                    NaN
# 1802                    NaN
# 1803                    NaN
#
#      Program to follow-up with (SH/BCCH program responsible)  External  \
# 0                                                   NaN       Internal
# 1                                                   NaN       External
# 2                                                   NaN       External
# 3                                                   NaN       Internal
# 4                             Positioning Mobility Team       External
# ...                                                 ...            ...
# 1799                                                NaN            NaN
# 1800                                                NaN            NaN
# 1801                                                NaN            NaN
# 1802                                                NaN            NaN
# 1803                                                NaN            NaN
#
#                Author(s) (or name of org. if no author) Date created  \
# 0                    Ivonne M. , OT & Stephanie G. , OT          NaN
# 1     Child-Bright Network and Strategy for Patient-...         2020
# 2                                                   NaN          NaN
# 3                            Jennifer Engle (BC Campus)          NaN
# 4                         University of Colorado Denver         2013
# ...                                                 ...          ...
# 1799                                                NaN          NaN
# 1800                                                NaN          NaN
# 1801                                                NaN          NaN
# 1802                                                NaN          NaN
# 1803                                                NaN          NaN
#
#      Date of last update (©related to website that is linked, not necessarily the resource)  \
# 0                                                   NaN
# 1                                                  2022
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                                                    Link  Date Link Checked  \
# 0                                                   NaN                NaN
# 1         https://www.child-bright.ca/virtual-symposium       May 31, 2022
# 2                           https://www.efpractice.com/                NaN
# 3     https://pressbooks.bccampus.ca/jengle/chapter/...  September 9, 2021
# 4     https://www1.ucdenver.edu/centers/center-for-i...          May 31-21
# ...                                                 ...                ...
# 1799                                                NaN                NaN
# 1800                                                NaN                NaN
# 1801                                                NaN                NaN
# 1802                                                NaN                NaN
# 1803                                                NaN                NaN
#
#                                    Target Audience File Format  \
# 0                                              NaN         NaN
# 1     clinicians, researchers, families/caregivers    Web link
# 2                                              NaN         NaN
# 3                                       clinicians    web link
# 4                          clinicians, researchers    web link
# ...                                            ...         ...
# 1799                                           NaN         NaN
# 1800                                           NaN         NaN
# 1801                                           NaN         NaN
# 1802                                           NaN         NaN
# 1803                                           NaN         NaN
#
#                           Master Tag (Level 1)  \
# 0                                          NaN
# 1                     Making Treatment Choices
# 2                                          NaN
# 3                                          NaN
# 4     Services, Supports & Community Resources
# ...                                        ...
# 1799                                       NaN
# 1800                                       NaN
# 1801                                       NaN
# 1802                                       NaN
# 1803                                       NaN
#
#                                         Level 2A  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                        Learn About Assessments
# ...                                          ...
# 1799                                         NaN
# 1800                                         NaN
# 1801                                         NaN
# 1802                                         NaN
# 1803                                         NaN
#
#                                        Level 3A Level 4A  \
# 0                                           NaN      NaN
# 1     Function, Activity and 'How To' Resources      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                    Other Assessment Resources      NaN
# ...                                         ...      ...
# 1799                                        NaN      NaN
# 1800                                        NaN      NaN
# 1801                                        NaN      NaN
# 1802                                        NaN      NaN
# 1803                                        NaN      NaN
#
#                                         Level 2B  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1799                                         NaN
# 1800                                         NaN
# 1801                                         NaN
# 1802                                         NaN
# 1803                                         NaN
#
#                                  Level 3B Level 4B Level 2C Level 3C Level 4C  \
# 0                                     NaN      NaN      NaN      NaN      NaN
# 1     Health Condition-specific Resources      NaN      NaN      NaN      NaN
# 2                                     NaN      NaN      NaN      NaN      NaN
# 3                                     NaN      NaN      NaN      NaN      NaN
# 4                                     NaN      NaN      NaN      NaN      NaN
# ...                                   ...      ...      ...      ...      ...
# 1799                                  NaN      NaN      NaN      NaN      NaN
# 1800                                  NaN      NaN      NaN      NaN      NaN
# 1801                                  NaN      NaN      NaN      NaN      NaN
# 1802                                  NaN      NaN      NaN      NaN      NaN
# 1803                                  NaN      NaN      NaN      NaN      NaN
#
#                                             Description  \
# 0                                                   NaN
# 1     The 2020 CHILD-BRIGHT Virtual Symposium was a ...
# 2                                                   NaN
# 3     Resource that aids in understanding factors to...
# 4     Resources that promote the adoption and use of...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                                        Health condition  \
# 0                                                   DCD
# 1                                                 Other
# 2                                                   NaN
# 3                                 no specific diagnosis
# 4     Cerebral palsy , Brain injury, concussion, Dev...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                                           Area of Focus  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Positioning, mobility, lower body, Assistive t...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                 Keywords (see tags tab for information)  \
# 0                                                   NaN
# 1     webinars, congenital heart disease, genomic te...
# 2                                                   NaN
# 3     assessment, test, IQ, disability, special popu...
# 4     wheelchair, mobility, assistive device, evalua...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#      Learning Event?  (Y/N)  \
# 0                         N
# 1                         Y
# 2                       NaN
# 3                         N
# 4                         N
# ...                     ...
# 1799                    NaN
# 1800                    NaN
# 1801                    NaN
# 1802                    NaN
# 1803                    NaN
#
#                 Corresponding clinician/parent resource  \
# 0     Management of Developmental Coordination Disor...
# 1                                                     N
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    N
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                     Sibling resources e.g. next steps Notes  \
# 0     DCD saved search; DCD management brief overview   NaN
# 1                                                   N   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# ...                                               ...   ...
# 1799                                              NaN   NaN
# 1800                                              NaN   NaN
# 1801                                              NaN   NaN
# 1802                                              NaN   NaN
# 1803                                              NaN   NaN
#
#      Person recommending  Age     Location Thumbnails Accessibility
# 0              Ivonne M.  NaN          NaN        NaN           NaN
# 1                    Kim  All  Canada-Wide        NaN           NaN
# 2            Michelle L.  NaN          NaN        NaN           NaN
# 3                Jen E.   All          NaN        NaN           NaN
# 4                 Debbie  All          USA        NaN           NaN
# ...                  ...  ...          ...        ...           ...
# 1799                 NaN  NaN          NaN        NaN           NaN
# 1800                 NaN  NaN          NaN        NaN           NaN
# 1801                 NaN  NaN          NaN        NaN           NaN
# 1802                 NaN  NaN          NaN        NaN           NaN
# 1803                 NaN  NaN          NaN        NaN           NaN
#
# [1804 rows x 38 columns]

# %%
#plotting the percentage of missing values in each column
data_length = len(new_data)
data_null = (new_data.isnull().sum().sort_values(ascending=False)*100/len(new_data))
f, ax = plt.subplots(figsize=(15, 12))
sns.set_color_codes("pastel")
sns.set_color_codes("pastel")
ax.set(xlim=(0, 100), ylabel="",
       xlabel="% Missing Values")
sns.barplot(x=data_null.values, y=data_null.index, color="b")
sns.despine()

# %%
new_data = new_data.drop([
    'Accessibility',
    'Thumbnails'
], axis = 1)

# %%
'''
new_data.rename(columns = {
    'Inventory ID':'Allows us to identify objects that are duplicated in the database, and link Digital Lab-generated ID#s to the objects in this spreadsheet',
    'Title':'These are the titles of the objects; can include terms in search filter; include on blade.',
    'Person responsible':'Part of algorthim prompting updates to content, so the appropriate person is alerted/contacted',
    'Others involved':'Use for algorithm to prompt updates to objects. These would be back-up people to support updates',
    'Required work':'only relevant when the object is not yet web-ready, or needs revisions (does not need to be part of database). ',
    'Target completion date':'For new or not yet updated content: ',
    'Program to follow-up with (SH/BCCH program responsible)':'Include in algorithm to prompt updates so we know where to go  (i.e. the program is responsible for maintaining the object)',
    'External':'Info to include on blade',
    'Author(s) (or name of org. if no author)':'Info to include on blade',
    'Date created':'Exclude from search terms; For internal use only (no longer to appear on the blade)',
    'Date of last update (©related to website that is linked, not necessarily the resource)':'Exclude from search term; Content - include on blade',
    'Link':'Exclude from search terms; Include on blade to allow users to access the external resource',
    'Date Link Checked':'For algorithm to prompt us to update object for currency',
    'Target Audience':'Unnamed: 24',
    'File Format':'For internal use so the person uploading the resource knows what type of file format to save it in or look for to upload',
    'Master Tag (Level 1)':'Navigation',
    'Level 2A':'Navigation.1',
    'Level 3A':'Navigation.2',
    'Level 4A':'Navigation.3',
    'Level 2B':'Navigation.4',
    'Level 3B':'Navigation.5',
    'Level 4B':'Navigation.6',
    'Level 2C':'Navigation.7',
    'Level 3C':'Navigation.8',
    'Level 4C':'Navigation.9',
    'Description':'Content to include on blade; exclude from search terms',
    'Health condition':'Filter',
    'Area of Focus':'Filter.1',
    'Keywords (see tags tab for information)':'Search terms',
    'Learning Event?  (Y/N)':'Filter.2',
    'Corresponding clinician/parent resource':'Toggle for audience (clinician vs. family)',
    'Sibling resources e.g. next steps':'Recommended for you\' tag (algorithm for proposing new resources for the user to explore)',
    'Notes':'For internal use in the database.',
    'Person recommending':'Used within algorithm to prompt updates to objects - directs us to the relevant content expert',
    'Age':'Filter',
    'Location':'This information can populate a field on the \'blade\' for each object',
    'Thumbnails':'Thumbnail images for each object for users to see when browsing',
    'Accessibility':'Content - object \'rating\' based on accessibility characteristics. Rating levels TBD. Could be on the blades or could be an icon on the thumbnail view (advise as to which is best approach)'
}, inplace = True)
'''

# %%
new_data_dropped_ID_Title = new_data.drop_duplicates(subset='Inventory ID', keep="first")
new_data_dropped_ID_Title = new_data.drop_duplicates(subset='Title', keep="first")
new_data_dropped_ID_Title.reset_index(drop=True)
new_data_dropped_ID_Title
# Out:
#      Inventory ID                                              Title  \
# 0               1  [insert other DCD Advocacy Toolkit resources] ...
# 1               2  2020 Child-Bright Virtual Symposium Session Re...
# 2               3                          360 Cognitive Connections
# 3               4  5. Plan A: Standardized measures of IQ and dev...
# 4               6  A Clinical Application Guide to Standardized W...
# ...           ...                                                ...
# 1680         1477                                  Right Review Tool
# 1681         1478  Today's Kids in Motion magazine for parents ra...
# 1682         1479  Centre for Accessible Post-Secondary Education...
# 1683         1480  Academic Communication Equity-British Columbia...
# 1684         1481            Sunny Hill Health Centre - Our Services
#
#      Person responsible Others involved                         Required work  \
# 0             Stephanie         Jill Z.  Review to ensure web-ready; add tags
# 1         Claire/Salina             NaN                                   NaN
# 2                Claire             NaN                                   NaN
# 3                Claire             NaN                                   NaN
# 4                Debbie             NaN                                   NaN
# ...                 ...             ...                                   ...
# 1680          Stephanie             NaN                                   NaN
# 1681             Debbie             NaN                                   NaN
# 1682             Debbie             NaN                                   NaN
# 1683             Debbie             NaN                                   NaN
# 1684              Tanja             NaN                                   add
#
#      Target completion date  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1680                    NaN
# 1681                    NaN
# 1682                    NaN
# 1683                    NaN
# 1684                    NaN
#
#      Program to follow-up with (SH/BCCH program responsible)  External  \
# 0                                                   NaN       Internal
# 1                                                   NaN       External
# 2                                                   NaN       External
# 3                                                   NaN       Internal
# 4                             Positioning Mobility Team       External
# ...                                                 ...            ...
# 1680                                                NaN       External
# 1681                                                NaN       External
# 1682                                                NaN       External
# 1683                                                NaN       External
# 1684                                                NaN       Internal
#
#                Author(s) (or name of org. if no author) Date created  \
# 0                    Ivonne M. , OT & Stephanie G. , OT          NaN
# 1     Child-Bright Network and Strategy for Patient-...         2020
# 2                                                   NaN          NaN
# 3                            Jennifer Engle (BC Campus)          NaN
# 4                         University of Colorado Denver         2013
# ...                                                 ...          ...
# 1680                                      Andrea Tricco          NaN
# 1681                                          BCS Group      unknown
# 1682                                           CAPER-BC          NaN
# 1683                                             ACE-BC          NaN
# 1684                                               PHSA         2022
#
#      Date of last update (©related to website that is linked, not necessarily the resource)  \
# 0                                                   NaN
# 1                                                  2022
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1680                                               2022
# 1681                                                NaN
# 1682                                                NaN
# 1683                                                NaN
# 1684                                                NaN
#
#                                                    Link  Date Link Checked  \
# 0                                                   NaN                NaN
# 1         https://www.child-bright.ca/virtual-symposium       May 31, 2022
# 2                           https://www.efpractice.com/                NaN
# 3     https://pressbooks.bccampus.ca/jengle/chapter/...  September 9, 2021
# 4     https://www1.ucdenver.edu/centers/center-for-i...          May 31-21
# ...                                                 ...                ...
# 1680       https://rightreview.knowledgetranslation.net        May 4, 2022
# 1681                          https://www.todayskids.ca          May 12-22
# 1682                                 https://caperbc.ca          May 12-22
# 1683                                 https://ace-bc.ca/          May 12-22
# 1684  http://www.bcchildrens.ca/our-services/sunny-h...        May 27 2022
#
#                                         Target Audience File Format  \
# 0                                                   NaN         NaN
# 1          clinicians, researchers, families/caregivers    Web link
# 2                                                   NaN         NaN
# 3                                            clinicians    web link
# 4                               clinicians, researchers    web link
# ...                                                 ...         ...
# 1680                                        Researchers    web link
# 1681         Families/caregivers, Clinicians, Educators    web link
# 1682  Educators, Children/youth, Families/caregivers...    web link
# 1683  Educators, Children/youth, Families/caregivers...    web link
# 1684  Clinicians, Families/caregivers, Educators, Re...    web link
#
#                                    Master Tag (Level 1)  \
# 0                                                   NaN
# 1                              Making Treatment Choices
# 2                                                   NaN
# 3                                                   NaN
# 4              Services, Supports & Community Resources
# ...                                                 ...
# 1680  Tools to Find, Evaluate and Use Health Informa...
# 1681           Services, Supports & Community Resources
# 1682           Services, Supports & Community Resources
# 1683           Services, Supports & Community Resources
# 1684           Services, Supports & Community Resources
#
#                                         Level 2A  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                        Learn About Assessments
# ...                                          ...
# 1680    Move Evidence into Action (Step 4 and 5)
# 1681           Recreation and Leisure Activities
# 1682              Age and Healthcare Transitions
# 1683              Age and Healthcare Transitions
# 1684        Find Care and Support Services in BC
#
#                                              Level 3A  \
# 0                                                 NaN
# 1           Function, Activity and 'How To' Resources
# 2                                                 NaN
# 3                                                 NaN
# 4                          Other Assessment Resources
# ...                                               ...
# 1680  Create Knowledge Products (Knowledge Synthesis)
# 1681                                Physical Activity
# 1682                               Youth to Adulthood
# 1683                               Youth to Adulthood
# 1684                Assessment and Treatment Services
#
#                                                Level 4A  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1680                                   For Other Groups
# 1681                                                NaN
# 1682  Post-Secondary Education and Employment Resources
# 1683  Post-Secondary Education and Employment Resources
# 1684  BC Children's Hospital and Sunny Hill Health C...
#
#                                         Level 2B  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1680                                         NaN
# 1681           Recreation and Leisure Activities
# 1682                      Equipment and Supplies
# 1683        Find Care and Support Services in BC
# 1684                                         NaN
#
#                                  Level 3B Level 4B  \
# 0                                     NaN      NaN
# 1     Health Condition-specific Resources      NaN
# 2                                     NaN      NaN
# 3                                     NaN      NaN
# 4                                     NaN      NaN
# ...                                   ...      ...
# 1680                                  NaN      NaN
# 1681           Arts and Cultural Programs      NaN
# 1682                                  NaN      NaN
# 1683                      School Supports      NaN
# 1684                                  NaN      NaN
#
#                                   Level 2C         Level 3C Level 4C  \
# 0                                      NaN              NaN      NaN
# 1                                      NaN              NaN      NaN
# 2                                      NaN              NaN      NaN
# 3                                      NaN              NaN      NaN
# 4                                      NaN              NaN      NaN
# ...                                    ...              ...      ...
# 1680                                   NaN              NaN      NaN
# 1681    Advocating for Your Family's Needs              NaN      NaN
# 1682  Find Care and Support Services in BC  School Supports      NaN
# 1683                                   NaN              NaN      NaN
# 1684                                   NaN              NaN      NaN
#
#                                             Description  \
# 0                                                   NaN
# 1     The 2020 CHILD-BRIGHT Virtual Symposium was a ...
# 2                                                   NaN
# 3     Resource that aids in understanding factors to...
# 4     Resources that promote the adoption and use of...
# ...                                                 ...
# 1680  This tool provides guidance and supporting mat...
# 1681  Online publication providing exchange of infor...
# 1682  provides accessible learning and teaching mate...
# 1683  provides expertise and resources for equal acc...
# 1684  Provides links to services offered by the Sunn...
#
#                                        Health condition  \
# 0                                                   DCD
# 1                                                 Other
# 2                                                   NaN
# 3                                 no specific diagnosis
# 4     Cerebral palsy , Brain injury, concussion, Dev...
# ...                                                 ...
# 1680                                                NaN
# 1681                                                All
# 1682                                                All
# 1683                            Hearing and vision loss
# 1684                                                All
#
#                                           Area of Focus  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Positioning, mobility, lower body, Assistive t...
# ...                                                 ...
# 1680                                                NaN
# 1681                                                All
# 1682  Learning, education, Vision, hearing, touch, o...
# 1683  Learning, education, Vision, hearing, touch, o...
# 1684                                                All
#
#                 Keywords (see tags tab for information)  \
# 0                                                   NaN
# 1     webinars, congenital heart disease, genomic te...
# 2                                                   NaN
# 3     assessment, test, IQ, disability, special popu...
# 4     wheelchair, mobility, assistive device, evalua...
# ...                                                 ...
# 1680                                                NaN
# 1681  health, lifestyle, participation, acceptance, ...
# 1682  alternate print format, accessibility, learnin...
# 1683  speech to text, transcription, assistive liste...
# 1684  Services, Sunny Hill health centre for childre...
#
#      Learning Event?  (Y/N)  \
# 0                         N
# 1                         Y
# 2                       NaN
# 3                         N
# 4                         N
# ...                     ...
# 1680                    NaN
# 1681                      N
# 1682                      N
# 1683                      N
# 1684                      N
#
#                 Corresponding clinician/parent resource  \
# 0     Management of Developmental Coordination Disor...
# 1                                                     N
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    N
# ...                                                 ...
# 1680                                                NaN
# 1681                                                  N
# 1682                                                  N
# 1683                                                  N
# 1684                                                  N
#
#                     Sibling resources e.g. next steps Notes  \
# 0     DCD saved search; DCD management brief overview   NaN
# 1                                                   N   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# ...                                               ...   ...
# 1680                                              NaN   NaN
# 1681                                              NaN   NaN
# 1682                                              NaN   NaN
# 1683                                              NaN   NaN
# 1684                                              NaN   NaN
#
#      Person recommending                   Age     Location
# 0              Ivonne M.                   NaN          NaN
# 1                    Kim                   All  Canada-Wide
# 2            Michelle L.                   NaN          NaN
# 3                Jen E.                    All          NaN
# 4                 Debbie                   All          USA
# ...                  ...                   ...          ...
# 1680                 NaN                   NaN          NaN
# 1681              Debbie                   All       Canada
# 1682              Debbie  Youth (15-19+ years)           BC
# 1683              Debbie  Youth (15-19+ years)           BC
# 1684               Tanja  Youth (15-19+ years)           BC
#
# [1373 rows x 36 columns]

# %%
new_data_dropped_ID_Title.to_csv('new_data_dropped_ID_Title.csv', index=False)

# %%
new_data_dropped_ID = new_data.drop_duplicates(subset='Inventory ID', keep="first")
new_data_dropped_ID.reset_index(drop=True)
new_data_dropped_ID.reset_index(drop=True)
new_data_dropped_ID
# Out:
#      Inventory ID                                              Title  \
# 0               1  [insert other DCD Advocacy Toolkit resources] ...
# 1               2  2020 Child-Bright Virtual Symposium Session Re...
# 2               3                          360 Cognitive Connections
# 3               4  5. Plan A: Standardized measures of IQ and dev...
# 4               6  A Clinical Application Guide to Standardized W...
# ...           ...                                                ...
# 1799         1596                                                NaN
# 1800         1597                                                NaN
# 1801         1598                                                NaN
# 1802         1599                                                NaN
# 1803         1600                                                NaN
#
#      Person responsible Others involved                         Required work  \
# 0             Stephanie         Jill Z.  Review to ensure web-ready; add tags
# 1         Claire/Salina             NaN                                   NaN
# 2                Claire             NaN                                   NaN
# 3                Claire             NaN                                   NaN
# 4                Debbie             NaN                                   NaN
# ...                 ...             ...                                   ...
# 1799                NaN             NaN                                   NaN
# 1800                NaN             NaN                                   NaN
# 1801                NaN             NaN                                   NaN
# 1802                NaN             NaN                                   NaN
# 1803                NaN             NaN                                   NaN
#
#      Target completion date  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1799                    NaN
# 1800                    NaN
# 1801                    NaN
# 1802                    NaN
# 1803                    NaN
#
#      Program to follow-up with (SH/BCCH program responsible)  External  \
# 0                                                   NaN       Internal
# 1                                                   NaN       External
# 2                                                   NaN       External
# 3                                                   NaN       Internal
# 4                             Positioning Mobility Team       External
# ...                                                 ...            ...
# 1799                                                NaN            NaN
# 1800                                                NaN            NaN
# 1801                                                NaN            NaN
# 1802                                                NaN            NaN
# 1803                                                NaN            NaN
#
#                Author(s) (or name of org. if no author) Date created  \
# 0                    Ivonne M. , OT & Stephanie G. , OT          NaN
# 1     Child-Bright Network and Strategy for Patient-...         2020
# 2                                                   NaN          NaN
# 3                            Jennifer Engle (BC Campus)          NaN
# 4                         University of Colorado Denver         2013
# ...                                                 ...          ...
# 1799                                                NaN          NaN
# 1800                                                NaN          NaN
# 1801                                                NaN          NaN
# 1802                                                NaN          NaN
# 1803                                                NaN          NaN
#
#      Date of last update (©related to website that is linked, not necessarily the resource)  \
# 0                                                   NaN
# 1                                                  2022
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                                                    Link  Date Link Checked  \
# 0                                                   NaN                NaN
# 1         https://www.child-bright.ca/virtual-symposium       May 31, 2022
# 2                           https://www.efpractice.com/                NaN
# 3     https://pressbooks.bccampus.ca/jengle/chapter/...  September 9, 2021
# 4     https://www1.ucdenver.edu/centers/center-for-i...          May 31-21
# ...                                                 ...                ...
# 1799                                                NaN                NaN
# 1800                                                NaN                NaN
# 1801                                                NaN                NaN
# 1802                                                NaN                NaN
# 1803                                                NaN                NaN
#
#                                    Target Audience File Format  \
# 0                                              NaN         NaN
# 1     clinicians, researchers, families/caregivers    Web link
# 2                                              NaN         NaN
# 3                                       clinicians    web link
# 4                          clinicians, researchers    web link
# ...                                            ...         ...
# 1799                                           NaN         NaN
# 1800                                           NaN         NaN
# 1801                                           NaN         NaN
# 1802                                           NaN         NaN
# 1803                                           NaN         NaN
#
#                           Master Tag (Level 1)  \
# 0                                          NaN
# 1                     Making Treatment Choices
# 2                                          NaN
# 3                                          NaN
# 4     Services, Supports & Community Resources
# ...                                        ...
# 1799                                       NaN
# 1800                                       NaN
# 1801                                       NaN
# 1802                                       NaN
# 1803                                       NaN
#
#                                         Level 2A  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                        Learn About Assessments
# ...                                          ...
# 1799                                         NaN
# 1800                                         NaN
# 1801                                         NaN
# 1802                                         NaN
# 1803                                         NaN
#
#                                        Level 3A Level 4A  \
# 0                                           NaN      NaN
# 1     Function, Activity and 'How To' Resources      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                    Other Assessment Resources      NaN
# ...                                         ...      ...
# 1799                                        NaN      NaN
# 1800                                        NaN      NaN
# 1801                                        NaN      NaN
# 1802                                        NaN      NaN
# 1803                                        NaN      NaN
#
#                                         Level 2B  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1799                                         NaN
# 1800                                         NaN
# 1801                                         NaN
# 1802                                         NaN
# 1803                                         NaN
#
#                                  Level 3B Level 4B Level 2C Level 3C Level 4C  \
# 0                                     NaN      NaN      NaN      NaN      NaN
# 1     Health Condition-specific Resources      NaN      NaN      NaN      NaN
# 2                                     NaN      NaN      NaN      NaN      NaN
# 3                                     NaN      NaN      NaN      NaN      NaN
# 4                                     NaN      NaN      NaN      NaN      NaN
# ...                                   ...      ...      ...      ...      ...
# 1799                                  NaN      NaN      NaN      NaN      NaN
# 1800                                  NaN      NaN      NaN      NaN      NaN
# 1801                                  NaN      NaN      NaN      NaN      NaN
# 1802                                  NaN      NaN      NaN      NaN      NaN
# 1803                                  NaN      NaN      NaN      NaN      NaN
#
#                                             Description  \
# 0                                                   NaN
# 1     The 2020 CHILD-BRIGHT Virtual Symposium was a ...
# 2                                                   NaN
# 3     Resource that aids in understanding factors to...
# 4     Resources that promote the adoption and use of...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                                        Health condition  \
# 0                                                   DCD
# 1                                                 Other
# 2                                                   NaN
# 3                                 no specific diagnosis
# 4     Cerebral palsy , Brain injury, concussion, Dev...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                                           Area of Focus  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Positioning, mobility, lower body, Assistive t...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                 Keywords (see tags tab for information)  \
# 0                                                   NaN
# 1     webinars, congenital heart disease, genomic te...
# 2                                                   NaN
# 3     assessment, test, IQ, disability, special popu...
# 4     wheelchair, mobility, assistive device, evalua...
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#      Learning Event?  (Y/N)  \
# 0                         N
# 1                         Y
# 2                       NaN
# 3                         N
# 4                         N
# ...                     ...
# 1799                    NaN
# 1800                    NaN
# 1801                    NaN
# 1802                    NaN
# 1803                    NaN
#
#                 Corresponding clinician/parent resource  \
# 0     Management of Developmental Coordination Disor...
# 1                                                     N
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    N
# ...                                                 ...
# 1799                                                NaN
# 1800                                                NaN
# 1801                                                NaN
# 1802                                                NaN
# 1803                                                NaN
#
#                     Sibling resources e.g. next steps Notes  \
# 0     DCD saved search; DCD management brief overview   NaN
# 1                                                   N   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# ...                                               ...   ...
# 1799                                              NaN   NaN
# 1800                                              NaN   NaN
# 1801                                              NaN   NaN
# 1802                                              NaN   NaN
# 1803                                              NaN   NaN
#
#      Person recommending  Age     Location
# 0              Ivonne M.  NaN          NaN
# 1                    Kim  All  Canada-Wide
# 2            Michelle L.  NaN          NaN
# 3                Jen E.   All          NaN
# 4                 Debbie  All          USA
# ...                  ...  ...          ...
# 1799                 NaN  NaN          NaN
# 1800                 NaN  NaN          NaN
# 1801                 NaN  NaN          NaN
# 1802                 NaN  NaN          NaN
# 1803                 NaN  NaN          NaN
#
# [1503 rows x 36 columns]

# %%
new_data_dropped_ID.to_csv('new_data_dropped_ID', index=False)

# %%
new_data_dropped_Title = new_data.drop_duplicates(subset='Title', keep="first")
new_data_dropped_Title.reset_index(drop=True)
new_data_dropped_Title
# Out:
#      Inventory ID                                              Title  \
# 0               1  [insert other DCD Advocacy Toolkit resources] ...
# 1               2  2020 Child-Bright Virtual Symposium Session Re...
# 2               3                          360 Cognitive Connections
# 3               4  5. Plan A: Standardized measures of IQ and dev...
# 4               6  A Clinical Application Guide to Standardized W...
# ...           ...                                                ...
# 1680         1477                                  Right Review Tool
# 1681         1478  Today's Kids in Motion magazine for parents ra...
# 1682         1479  Centre for Accessible Post-Secondary Education...
# 1683         1480  Academic Communication Equity-British Columbia...
# 1684         1481            Sunny Hill Health Centre - Our Services
#
#      Person responsible Others involved                         Required work  \
# 0             Stephanie         Jill Z.  Review to ensure web-ready; add tags
# 1         Claire/Salina             NaN                                   NaN
# 2                Claire             NaN                                   NaN
# 3                Claire             NaN                                   NaN
# 4                Debbie             NaN                                   NaN
# ...                 ...             ...                                   ...
# 1680          Stephanie             NaN                                   NaN
# 1681             Debbie             NaN                                   NaN
# 1682             Debbie             NaN                                   NaN
# 1683             Debbie             NaN                                   NaN
# 1684              Tanja             NaN                                   add
#
#      Target completion date  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1680                    NaN
# 1681                    NaN
# 1682                    NaN
# 1683                    NaN
# 1684                    NaN
#
#      Program to follow-up with (SH/BCCH program responsible)  External  \
# 0                                                   NaN       Internal
# 1                                                   NaN       External
# 2                                                   NaN       External
# 3                                                   NaN       Internal
# 4                             Positioning Mobility Team       External
# ...                                                 ...            ...
# 1680                                                NaN       External
# 1681                                                NaN       External
# 1682                                                NaN       External
# 1683                                                NaN       External
# 1684                                                NaN       Internal
#
#                Author(s) (or name of org. if no author) Date created  \
# 0                    Ivonne M. , OT & Stephanie G. , OT          NaN
# 1     Child-Bright Network and Strategy for Patient-...         2020
# 2                                                   NaN          NaN
# 3                            Jennifer Engle (BC Campus)          NaN
# 4                         University of Colorado Denver         2013
# ...                                                 ...          ...
# 1680                                      Andrea Tricco          NaN
# 1681                                          BCS Group      unknown
# 1682                                           CAPER-BC          NaN
# 1683                                             ACE-BC          NaN
# 1684                                               PHSA         2022
#
#      Date of last update (©related to website that is linked, not necessarily the resource)  \
# 0                                                   NaN
# 1                                                  2022
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1680                                               2022
# 1681                                                NaN
# 1682                                                NaN
# 1683                                                NaN
# 1684                                                NaN
#
#                                                    Link  Date Link Checked  \
# 0                                                   NaN                NaN
# 1         https://www.child-bright.ca/virtual-symposium       May 31, 2022
# 2                           https://www.efpractice.com/                NaN
# 3     https://pressbooks.bccampus.ca/jengle/chapter/...  September 9, 2021
# 4     https://www1.ucdenver.edu/centers/center-for-i...          May 31-21
# ...                                                 ...                ...
# 1680       https://rightreview.knowledgetranslation.net        May 4, 2022
# 1681                          https://www.todayskids.ca          May 12-22
# 1682                                 https://caperbc.ca          May 12-22
# 1683                                 https://ace-bc.ca/          May 12-22
# 1684  http://www.bcchildrens.ca/our-services/sunny-h...        May 27 2022
#
#                                         Target Audience File Format  \
# 0                                                   NaN         NaN
# 1          clinicians, researchers, families/caregivers    Web link
# 2                                                   NaN         NaN
# 3                                            clinicians    web link
# 4                               clinicians, researchers    web link
# ...                                                 ...         ...
# 1680                                        Researchers    web link
# 1681         Families/caregivers, Clinicians, Educators    web link
# 1682  Educators, Children/youth, Families/caregivers...    web link
# 1683  Educators, Children/youth, Families/caregivers...    web link
# 1684  Clinicians, Families/caregivers, Educators, Re...    web link
#
#                                    Master Tag (Level 1)  \
# 0                                                   NaN
# 1                              Making Treatment Choices
# 2                                                   NaN
# 3                                                   NaN
# 4              Services, Supports & Community Resources
# ...                                                 ...
# 1680  Tools to Find, Evaluate and Use Health Informa...
# 1681           Services, Supports & Community Resources
# 1682           Services, Supports & Community Resources
# 1683           Services, Supports & Community Resources
# 1684           Services, Supports & Community Resources
#
#                                         Level 2A  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                        Learn About Assessments
# ...                                          ...
# 1680    Move Evidence into Action (Step 4 and 5)
# 1681           Recreation and Leisure Activities
# 1682              Age and Healthcare Transitions
# 1683              Age and Healthcare Transitions
# 1684        Find Care and Support Services in BC
#
#                                              Level 3A  \
# 0                                                 NaN
# 1           Function, Activity and 'How To' Resources
# 2                                                 NaN
# 3                                                 NaN
# 4                          Other Assessment Resources
# ...                                               ...
# 1680  Create Knowledge Products (Knowledge Synthesis)
# 1681                                Physical Activity
# 1682                               Youth to Adulthood
# 1683                               Youth to Adulthood
# 1684                Assessment and Treatment Services
#
#                                                Level 4A  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1680                                   For Other Groups
# 1681                                                NaN
# 1682  Post-Secondary Education and Employment Resources
# 1683  Post-Secondary Education and Employment Resources
# 1684  BC Children's Hospital and Sunny Hill Health C...
#
#                                         Level 2B  \
# 0                                            NaN
# 1     Learn About Treatment, Care and Activities
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1680                                         NaN
# 1681           Recreation and Leisure Activities
# 1682                      Equipment and Supplies
# 1683        Find Care and Support Services in BC
# 1684                                         NaN
#
#                                  Level 3B Level 4B  \
# 0                                     NaN      NaN
# 1     Health Condition-specific Resources      NaN
# 2                                     NaN      NaN
# 3                                     NaN      NaN
# 4                                     NaN      NaN
# ...                                   ...      ...
# 1680                                  NaN      NaN
# 1681           Arts and Cultural Programs      NaN
# 1682                                  NaN      NaN
# 1683                      School Supports      NaN
# 1684                                  NaN      NaN
#
#                                   Level 2C         Level 3C Level 4C  \
# 0                                      NaN              NaN      NaN
# 1                                      NaN              NaN      NaN
# 2                                      NaN              NaN      NaN
# 3                                      NaN              NaN      NaN
# 4                                      NaN              NaN      NaN
# ...                                    ...              ...      ...
# 1680                                   NaN              NaN      NaN
# 1681    Advocating for Your Family's Needs              NaN      NaN
# 1682  Find Care and Support Services in BC  School Supports      NaN
# 1683                                   NaN              NaN      NaN
# 1684                                   NaN              NaN      NaN
#
#                                             Description  \
# 0                                                   NaN
# 1     The 2020 CHILD-BRIGHT Virtual Symposium was a ...
# 2                                                   NaN
# 3     Resource that aids in understanding factors to...
# 4     Resources that promote the adoption and use of...
# ...                                                 ...
# 1680  This tool provides guidance and supporting mat...
# 1681  Online publication providing exchange of infor...
# 1682  provides accessible learning and teaching mate...
# 1683  provides expertise and resources for equal acc...
# 1684  Provides links to services offered by the Sunn...
#
#                                        Health condition  \
# 0                                                   DCD
# 1                                                 Other
# 2                                                   NaN
# 3                                 no specific diagnosis
# 4     Cerebral palsy , Brain injury, concussion, Dev...
# ...                                                 ...
# 1680                                                NaN
# 1681                                                All
# 1682                                                All
# 1683                            Hearing and vision loss
# 1684                                                All
#
#                                           Area of Focus  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Positioning, mobility, lower body, Assistive t...
# ...                                                 ...
# 1680                                                NaN
# 1681                                                All
# 1682  Learning, education, Vision, hearing, touch, o...
# 1683  Learning, education, Vision, hearing, touch, o...
# 1684                                                All
#
#                 Keywords (see tags tab for information)  \
# 0                                                   NaN
# 1     webinars, congenital heart disease, genomic te...
# 2                                                   NaN
# 3     assessment, test, IQ, disability, special popu...
# 4     wheelchair, mobility, assistive device, evalua...
# ...                                                 ...
# 1680                                                NaN
# 1681  health, lifestyle, participation, acceptance, ...
# 1682  alternate print format, accessibility, learnin...
# 1683  speech to text, transcription, assistive liste...
# 1684  Services, Sunny Hill health centre for childre...
#
#      Learning Event?  (Y/N)  \
# 0                         N
# 1                         Y
# 2                       NaN
# 3                         N
# 4                         N
# ...                     ...
# 1680                    NaN
# 1681                      N
# 1682                      N
# 1683                      N
# 1684                      N
#
#                 Corresponding clinician/parent resource  \
# 0     Management of Developmental Coordination Disor...
# 1                                                     N
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    N
# ...                                                 ...
# 1680                                                NaN
# 1681                                                  N
# 1682                                                  N
# 1683                                                  N
# 1684                                                  N
#
#                     Sibling resources e.g. next steps Notes  \
# 0     DCD saved search; DCD management brief overview   NaN
# 1                                                   N   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# ...                                               ...   ...
# 1680                                              NaN   NaN
# 1681                                              NaN   NaN
# 1682                                              NaN   NaN
# 1683                                              NaN   NaN
# 1684                                              NaN   NaN
#
#      Person recommending                   Age     Location
# 0              Ivonne M.                   NaN          NaN
# 1                    Kim                   All  Canada-Wide
# 2            Michelle L.                   NaN          NaN
# 3                Jen E.                    All          NaN
# 4                 Debbie                   All          USA
# ...                  ...                   ...          ...
# 1680                 NaN                   NaN          NaN
# 1681              Debbie                   All       Canada
# 1682              Debbie  Youth (15-19+ years)           BC
# 1683              Debbie  Youth (15-19+ years)           BC
# 1684               Tanja  Youth (15-19+ years)           BC
#
# [1373 rows x 36 columns]
